# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('scores_data.csv')
df.head()
# Out:
#        Batch  User_ID     Score
# 0  AI_ELITE_7  uid_149       6 / 7
# 1  AI_ELITE_7  uid_148       6 / 7
# 2  AI_ELITE_7  uid_147       7 / 7
# 3  AI_ELITE_7  uid_146       7 / 7
# 4  AI_ELITE_7  uid_145       4 / 7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Batch        149 non-null    object
#  1   User_ID      149 non-null    object
#  2      Score     149 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
df['Batch '].value_counts()
# Out:
# AI_ELITE_7    53
# AI_ELITE_6    48
# AI_ELITE_4    48
# Name: Batch , dtype: int64

# %%
df.shape
# Out:
# (149, 3)

# %%
df['   Score   '].value_counts()
# Out:
# 4 / 7    40
# 5 / 7    32
# 3 / 7    24
# 6 / 7    18
# 7 / 7    18
# 2 / 7    12
# 1 / 7     3
# 0 / 7     2
# Name:    Score   , dtype: int64

# %%
# so from the above study we have find that maximum score is 7 and 18 students got it.
df['new_score'] = df['   Score   '].map(eval)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Batch        149 non-null    object
#  1   User_ID      149 non-null    object
#  2      Score     149 non-null    object
#  3   new_score    149 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 4.8+ KB

# %%
df.head()
# Out:
#        Batch  User_ID     Score     new_score
# 0  AI_ELITE_7  uid_149       6 / 7   0.857143
# 1  AI_ELITE_7  uid_148       6 / 7   0.857143
# 2  AI_ELITE_7  uid_147       7 / 7   1.000000
# 3  AI_ELITE_7  uid_146       7 / 7   1.000000
# 4  AI_ELITE_7  uid_145       4 / 7   0.571429

# %%
df[df['new_score']>0.857143 ].value_counts()
# Out:
# Batch       User_ID      Score     new_score
# AI_ELITE_4  uid_10    7 / 7        1.0          1
#             uid_44    7 / 7        1.0          1
# AI_ELITE_7  uid_146   7 / 7        1.0          1
#             uid_144   7 / 7        1.0          1
#             uid_142   7 / 7        1.0          1
#             uid_134   7 / 7        1.0          1
#             uid_133   7 / 7        1.0          1
#             uid_132   7 / 7        1.0          1
#             uid_130   7 / 7        1.0          1
#             uid_125   7 / 7        1.0          1
#             uid_114   7 / 7        1.0          1
# AI_ELITE_6  uid_86    7 / 7        1.0          1
#             uid_82    7 / 7        1.0          1
#             uid_75    7 / 7        1.0          1
#             uid_71    7 / 7        1.0          1
#             uid_51    7 / 7        1.0          1
# AI_ELITE_4  uid_48    7 / 7        1.0          1
# AI_ELITE_7  uid_147   7 / 7        1.0          1
# dtype: int64

# %%
filterinfDataframe = df[(df['new_score'] > 0.857143) & (df['Batch '] == 'AI_ELITE_7') ]
filterinfDataframe.shape
# Out:
# (10, 4)

# %%
# so we got that 10 students of the AI_ELITE_7 Batch got the 7/7 marks in the exam.

# %%
import matplotlib.pyplot as plt
df.plot(x="Batch ",y="new_score",kind="line",figsize=(15,5))
plt.show()

# %%
df[df['new_score'] <0.142857].shape
# Out:
# (2, 4)

# %%
# Finally the 2 students are failed according to the data.
